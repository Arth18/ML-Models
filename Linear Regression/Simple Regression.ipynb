# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score , root_mean_squared_error 
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("ml 1 SLR.txt")

# %%
data
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
x = data.drop('price' , axis = 1)
y = data["price"]

# %%
plt.scatter(x,y)

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
model.predict([[5000],[6000],[7000]])
# Out:
# array([ 859554.79452055,  995342.46575342, 1131130.1369863 ])

# %%
y_predict = model.predict(x)

# %%
r2_score(y,y_predict)*100
# Out:
# 95.84301138199486

# %%
root_mean_squared_error(y,y_predict)
# Out:
# 13668.030893042014

# %%
d2 = pd.read_csv("ml 2 SLR.txt")

# %%
x = d2.drop("Sell Price", axis = 1)
y = d2['Sell Price']

# %%
plt.scatter(d2["Age"],y)
plt.ylabel("Price")
plt.xlabel("Age")
plt.show()

# %%
plt.scatter(d2["Mileage"],y)
plt.ylabel("Price")
plt.xlabel("Mileage")
plt.show()

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2, random_state=0)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ -0.36824743, 256.93238098])

# %%
model.intercept_
# Out:
# np.float64(46174.43945560081)

# %%
model.predict([[70000,7]])
# Out:
# array([22195.64585867])

# %%
y_pred = model.predict(x_test)

# %%
r2_score(y_test,y_pred)*100
# Out:
# 95.26977872660441

# %%
root_mean_squared_error(y_test,y_pred)
# Out:
# 2082.7788347059945
